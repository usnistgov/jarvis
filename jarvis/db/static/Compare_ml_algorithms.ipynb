# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis/blob/master/jarvis/db/static/Compare_ml_algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparison of ML models for classification and regression without hyperparameter optimization

# %% [markdown]
# ### Let's train classification and regression models for formations energy. A material will form if it has formation energy less than 0 and will not form if the formation energy is greater than 0. This is an example of classifcation problem. Predicting exact value of formation energies is a regression  problem. We'll compare some well-knowm ML methods for these problems.

# %%
# !pip install -U jarvis-tools lightgbm

# %%
from jarvis.db.static.explore_db import get_3d_dataset,get_2d_dataset,get_ml_dataset
from sklearn.model_selection import train_test_split
from jarvis.sklearn.build_models import *
from jarvis.sklearn.build_models import *
from jarvis.sklearn.build_models import jdata
from jarvis.sklearn.simple_models import simple_regression, binary_class_dat, bar_plot, simple_classification
from jarvis.db.static.explore_db import get_3d_dataset, get_2d_dataset, get_ml_dataset
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
import matplotlib
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings
warnings.filterwarnings('ignore')
import lightgbm as lgb
# %matplotlib inline

# %%
X, Y, jid=jdata(prop='form_enp')
# Out:
# Prop= form_enp 24759 24759

# %% [markdown]
# ### For quick training let's just take 500 samples. As an exercise, train the whole dataset later  by commenting the following lines.

# %%
X=X[0:500]
Y=Y[0:500]

# %% [markdown]
# ###Comparison of regression models

# %%
simple_regression(X,Y,plot=True)
# Out:
# GaussianProcessRegressor 1.158 1.43
# RandomForestRegressor 0.277 0.391
# GradientBoostingRegressor 0.232 0.296
# AdaBoostRegressor 0.357 0.446
# SVR 0.29 0.406
# Lasso 0.743 0.872
# LinearRegression 1.065 1.357
# KernelRidge 0.973 1.214
# MLPRegressor 0.502 0.703
# DecisionTreeRegressor 0.499 0.786

# %% [markdown]
# ###Comparison of classification models

# %%
simple_classification(X=X,Y=Y,tol=0,plot=True)
# Out:
# DecisionTreeClassifier 0.6325757575757576
# MLPClassifier 0.9431818181818181
# GradientBoostingClassifier 0.9166666666666666
# KNeighborsClassifier 0.6477272727272727
# GaussianProcessClassifier 0.5454545454545454
# RandomForestClassifier 0.8712121212121212
# AdaBoostClassifier 0.7878787878787878
# SVC 0.9810606060606061
