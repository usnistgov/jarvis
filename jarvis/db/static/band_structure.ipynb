# %%
import os
from jarvis.tools.vasp import bandstr,plot_dos
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 100
si_path = os.path.join(os.getcwd(), '..','..','vasp','examples','SiOptb88')
vasprun=os.path.join(si_path,'MAIN-BAND-bulk@mp_149','vasprun.xml')
kp_file=os.path.join(si_path,'MAIN-BAND-bulk@mp_149','KPOINTS')
band=bandstr(vrun=vasprun,kpfile=kp_file,filename='bandstr.jpg',plot=True)
band=bandstr(vrun=vasprun,kpfile=kp_file)
band.show()
# Out:
# C:\Users\kamal\Anaconda3\lib\site-packages\pymatgen-2019.1.13-py3.7-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\MAIN-BAND-bulk@mp_149
#   " was found in {}".format(os.path.abspath(p)))
# C:\Users\kamal\Anaconda3\lib\site-packages\pymatgen-2019.1.13-py3.7-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\MAIN-BAND-bulk@mp_149
#   " was found in {}".format(os.path.abspath(p)))

# %%
dos=plot_dos(vrun=vasprun,filename='.',plot=True)
# Out:
# C:\Users\kamal\Anaconda3\lib\site-packages\pymatgen-2019.1.13-py3.7-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\MAIN-BAND-bulk@mp_149
#   " was found in {}".format(os.path.abspath(p)))
