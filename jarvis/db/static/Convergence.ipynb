# %%
import os
from jarvis.tools.vasp import plot_enc_convergence,plot_kp_convergence
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
si_path = os.path.join(os.getcwd(), '..','..','vasp','examples','SiOptb88')

plot_enc_convergence(directory=si_path)
# Out:
# C:\Users\kamal\Anaconda3\envs\my_jupyter\lib\site-packages\pymatgen-2019.1.13-py3.6-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\ENCUTbulk@mp_149-500
#   " was found in {}".format(os.path.abspath(p)))
# C:\Users\kamal\Anaconda3\envs\my_jupyter\lib\site-packages\pymatgen-2019.1.13-py3.6-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\ENCUTbulk@mp_149-600
#   " was found in {}".format(os.path.abspath(p)))
# C:\Users\kamal\Anaconda3\envs\my_jupyter\lib\site-packages\pymatgen-2019.1.13-py3.6-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\ENCUTbulk@mp_149-650
# ...

# %%
plot_kp_convergence(directory=si_path)
# Out:
# C:\Users\kamal\Anaconda3\envs\my_jupyter\lib\site-packages\pymatgen-2019.1.13-py3.6-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\KPOINTSbulk@mp_149-10
#   " was found in {}".format(os.path.abspath(p)))
# C:\Users\kamal\Anaconda3\envs\my_jupyter\lib\site-packages\pymatgen-2019.1.13-py3.6-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\KPOINTSbulk@mp_149-15
#   " was found in {}".format(os.path.abspath(p)))
# C:\Users\kamal\Anaconda3\envs\my_jupyter\lib\site-packages\pymatgen-2019.1.13-py3.6-win-amd64.egg\pymatgen\io\vasp\outputs.py:879: UserWarning: No POTCAR file with matching TITEL fields was found in C:\Users\kamal\Downloads\jupyter\jarvis\jarvis\vasp\examples\SiOptb88\KPOINTSbulk@mp_149-20
# ...
